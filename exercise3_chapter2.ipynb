# %%
import RVC3 as rvc
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import math
from math import pi
np.set_printoptions(
    linewidth=120, formatter={
        'float': lambda x: f"{0:8.4g}" if abs(x) < 1e-10 else f"{x:8.4g}"})
np.random.seed(0)
from spatialmath import *
from spatialmath.base import *

# %% [markdown]
# create a 3d rotation matrix with a rotation of pi/4

# %%
R = rotx(0.78)
R
# Out:
# array([[       1,        0,        0],
#        [       0,   0.7109,  -0.7033],
#        [       0,   0.7033,   0.7109]])

# %% [markdown]
# plot the rotation

# %%
trplot(R)
# Out:
# <Axes3D: xlabel='X', ylabel='Y', zlabel='Z'>

# %% [markdown]
# define a vector (along the z axis) to be transformed

# %%
vector = np.array([0, 0, 3])

# %% [markdown]
# transform the vector using the rotation matrix

# %%
T_Vector = R @ vector 
T_Vector
# Out:
# array([       0,    -2.11,    2.133])

# %% [markdown]
# Using the transpose as an alternative to inv()

# %%
R_Inv = R.T
R_Inv
# Out:
# array([[       1,        0,        0],
#        [       0,   0.7109,   0.7033],
#        [       0,  -0.7033,   0.7109]])

# %% [markdown]
# multiply the rotation matrix by its inverse (2 cases)

# %%
R1 = R * R_Inv
R1
# Out:
# array([[       1,        0,        0],
#        [       0,   0.5054,  -0.4946],
#        [       0,  -0.4946,   0.5054]])

# %%
R2 = R_Inv * R
R2
# Out:
# array([[       1,        0,        0],
#        [       0,   0.5054,  -0.4946],
#        [       0,  -0.4946,   0.5054]])

# %% [markdown]
# calculate determinants of the rotation matrix and its inverse

# %%
det_R = np.linalg.det(R)
det_R
# Out:
# 1.0

# %%
det_R = np.linalg.det(R_Inv)
det_R
# Out:
# 1.0
